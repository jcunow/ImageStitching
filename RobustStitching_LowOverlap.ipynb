# %%
import os
import cv2
import numpy as np
from PIL import Image
from numpy.fft import fft2, ifft2

Image.MAX_IMAGE_PIXELS = None

# --- Utility functions ---
def list_files_with_pattern(directory_path, file_pattern):
    file_paths = []
    for root, _, files in os.walk(directory_path):
        for file in files:
            if file_pattern in file:
                file_paths.append(os.path.join(root, file))
    return file_paths

def list_unique_names_within_range(names_list, start_index, end_index):
    unique_names = set()
    for name in names_list:
        if len(name) > end_index:
            unique_names.add(name[start_index:end_index])
    return sorted(list(unique_names))

def elements_matching_pattern(input_list, pattern):
    return [element for element in input_list if pattern in element]

# --- Phase correlation (edge-based, relative shift) ---
def phase_correlation_alignment(img1, img2, edge_width=250, vertical_region=1000, vertical_offset=300):
    # Grayscale
    if len(img1.shape) == 3:
        img1_gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        img2_gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
    else:
        img1_gray = img1.copy()
        img2_gray = img2.copy()

    h1, w1 = img1_gray.shape[:2]
    h2, w2 = img2_gray.shape[:2]

    # Edge ROIs
    y_start1 = min(vertical_offset, max(0, h1 - vertical_region))
    y_start2 = min(vertical_offset, max(0, h2 - vertical_region))
    y_end1 = y_start1 + min(vertical_region, h1 - y_start1)
    y_end2 = y_start2 + min(vertical_region, h2 - y_start2)
    edge_width = min(edge_width, w1, w2)

    img1_edge = img1_gray[y_start1:y_end1, w1 - edge_width:]
    img2_edge = img2_gray[y_start2:y_end2, :edge_width]

    # FFT phase correlation on edge crops
    f1 = fft2(img1_edge.astype(np.float32))
    f2 = fft2(img2_edge.astype(np.float32))
    cps = (f1 * f2.conjugate()) / (np.abs(f1) * np.abs(f2) + 1e-10)
    corr = np.abs(ifft2(cps))
    dy_raw, dx_raw = np.unravel_index(np.argmax(corr), corr.shape)

    # Wrap
    if dy_raw > corr.shape[0] // 2:
        dy_raw -= corr.shape[0]
    if dx_raw > corr.shape[1] // 2:
        dx_raw -= corr.shape[1]

    # Relative shift between the two edge crops:
    dx_rel = -dx_raw
    dy_rel = -dy_raw
    return dx_rel, dy_rel

# --- Feature matching (edge-based, relative shift) ---
def feature_matching_alignment(img1, img2, edge_width=250, vertical_region=1000, vertical_offset=300, feature_method='sift'):
    # Grayscale
    if len(img1.shape) == 3:
        img1_gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        img2_gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
    else:
        img1_gray = img1.copy()
        img2_gray = img2.copy()

    h1, w1 = img1_gray.shape[:2]
    h2, w2 = img2_gray.shape[:2]

    # Edge ROIs
    y_start1 = min(vertical_offset, max(0, h1 - vertical_region))
    y_start2 = min(vertical_offset, max(0, h2 - vertical_region))
    y_end1 = y_start1 + min(vertical_region, h1 - y_start1)
    y_end2 = y_start2 + min(vertical_region, h2 - y_start2)
    edge_width = min(edge_width, w1, w2)

    img1_edge = img1_gray[y_start1:y_end1, w1 - edge_width:]
    img2_edge = img2_gray[y_start2:y_end2, :edge_width]

    # Create feature detector based on method
    feature_method = feature_method.lower()
    
    if feature_method == 'sift':
        detector = cv2.SIFT_create()
    elif feature_method == 'orb':
        detector = cv2.ORB_create(nfeatures=5000)
    elif feature_method == 'akaze':
        detector = cv2.AKAZE_create()
    elif feature_method == 'brisk':
        detector = cv2.BRISK_create()
    else:
        print(f"Warning: Unknown feature method '{feature_method}', using SIFT")
        detector = cv2.SIFT_create()

    # Detect features within edge ROIs
    kp1, des1 = detector.detectAndCompute(img1_edge, None)
    kp2, des2 = detector.detectAndCompute(img2_edge, None)

    if des1 is None or des2 is None:
        return 0, 0

    # Create matcher based on descriptor type
    if feature_method == 'orb' or feature_method == 'brisk' or feature_method == 'akaze':
        # Binary descriptors use Hamming distance
        bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=False)
    else:
        # SIFT uses L2 distance
        bf = cv2.BFMatcher(cv2.NORM_L2, crossCheck=False)

    matches = bf.knnMatch(des1, des2, k=2)

    # Lowe ratio test (adjust threshold for binary descriptors)
    ratio_threshold = 0.7 if feature_method in ['orb', 'brisk', 'akaze'] else 0.75
    good = []
    for match_pair in matches:
        if len(match_pair) == 2:
            m, n = match_pair
            if m.distance < ratio_threshold * n.distance:
                good.append(m)

    if len(good) < 4:
        return 0, 0

    src_pts = np.float32([kp1[m.queryIdx].pt for m in good]).reshape(-1, 1, 2)  # img1_edge
    dst_pts = np.float32([kp2[m.trainIdx].pt for m in good]).reshape(-1, 1, 2)  # img2_edge

    # Map img2_edge -> img1_edge
    M, mask = cv2.estimateAffinePartial2D(dst_pts, src_pts)
    if M is None:
        return 0, 0

    dx_rel = float(M[0, 2])
    dy_rel = float(M[1, 2])
    return dx_rel, dy_rel

# --- Create distortion map visualization ---
def create_distortion_map(disagreements, output_width, output_height, tile_positions):
    """
    Create a visual distortion map showing where alignment methods disagree most.
    
    Args:
        disagreements: List of (dx_abs, dy_abs, euclidean_distance) for each step
        output_width, output_height: Dimensions of the final stitched image
        tile_positions: List of approximate tile positions in the mosaic
    """
    # Create heatmap canvas
    distortion_map = np.zeros((output_height, output_width, 3), dtype=np.uint8)
    
    # Normalize disagreement values for color mapping
    euclidean_distances = [d[2] for d in disagreements]
    if euclidean_distances:
        max_disagreement = max(euclidean_distances)
        if max_disagreement > 0:
            # Create color map: blue (low disagreement) to red (high disagreement)
            for i, (dx_abs, dy_abs, euclidean) in enumerate(disagreements):
                if i < len(tile_positions):
                    x_pos, y_pos, width, height = tile_positions[i]
                    
                    # Normalize to 0-255 range
                    intensity = min(255, int(255 * euclidean / max_disagreement))
                    
                    # Create color: blue for low disagreement, red for high
                    color = (255 - intensity, 0, intensity)  # BGR format
                    
                    # Draw rectangle representing tile position with disagreement color
                    cv2.rectangle(distortion_map, 
                                (int(x_pos), int(y_pos)), 
                                (int(x_pos + width), int(y_pos + height)), 
                                color, -1)
                    
                    # Add text with disagreement values
                    text = f"{euclidean:.1f}"
                    cv2.putText(distortion_map, text, 
                              (int(x_pos + width//2 - 20), int(y_pos + height//2)), 
                              cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
    
    # Add legend
    legend_height = 50
    legend_width = output_width
    legend = np.zeros((legend_height, legend_width, 3), dtype=np.uint8)
    
    # Create gradient bar
    if euclidean_distances and max(euclidean_distances) > 0:
        gradient = np.linspace(0, 255, legend_width).astype(np.uint8)
        for i in range(legend_width):
            color = (255 - gradient[i], 0, gradient[i])
            legend[:, i] = color
        
        # Add text labels
        cv2.putText(legend, "Low Disagreement", (10, 35), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)
        cv2.putText(legend, "High Disagreement", (legend_width - 150, 35), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)
    
    # Combine distortion map and legend
    final_map = np.vstack([distortion_map, legend])
    
    return final_map

# --- Stitch two images with linear blending (same as your working version) ---
def stitch_two_images(img1_path, img2_path, method='phase', add_y_offset=False,
                      edge_width=250, vertical_region=1000, vertical_offset=300, feature_method='sift'):
    img1 = cv2.imread(img1_path)
    img2 = cv2.imread(img2_path)
    if img1 is None or img2 is None:
        raise ValueError(f"Could not load images: {img1_path}, {img2_path}")

    # Choose alignment method
    if method == 'phase':
        dx, dy = phase_correlation_alignment(img1, img2, edge_width=edge_width,
                                             vertical_region=vertical_region, vertical_offset=vertical_offset)
    elif method == 'feature':
        dx, dy = feature_matching_alignment(img1, img2, edge_width=edge_width,
                                            vertical_region=vertical_region, vertical_offset=vertical_offset,
                                            feature_method=feature_method)
    else:
        dx, dy = 0, 0

    # Y sign handling (keep your behavior)
    if not add_y_offset:
        dy = -dy

    # --- Linear blending (unchanged) ---
    h1, w1 = img1.shape[:2]
    h2, w2 = img2.shape[:2]

    calculated_overlap = edge_width - (-dx - (w2 - edge_width))
    actual_overlap = max(0, min(calculated_overlap, edge_width))
    img2_x_position = w1 - actual_overlap
    img2_y_position = int(round(dy))

    if img2_y_position >= 0:
        img1_y_start = 0
        img2_y_start = img2_y_position
        output_height = max(h1, h2 + img2_y_position)
    else:
        img1_y_start = -img2_y_position
        img2_y_start = 0
        output_height = max(h1 - img2_y_position, h2)

    output_width = img2_x_position + w2
    stitched = np.zeros((output_height, output_width, 3), dtype=np.uint8)
    stitched[img1_y_start:img1_y_start + h1, :w1] = img1

    if actual_overlap > 0:
        overlap_start = img2_x_position
        overlap_end = w1
        overlap_width = overlap_end - overlap_start
        blend_y_start = max(img1_y_start, img2_y_start)
        blend_y_end = min(img1_y_start + h1, img2_y_start + h2)
        if blend_y_end > blend_y_start and overlap_width > 0:
            blend_height = blend_y_end - blend_y_start
            alpha = np.linspace(1.0, 0.0, overlap_width).reshape(1, -1, 1)
            img1_region = img1[blend_y_start - img1_y_start:blend_y_start - img1_y_start + blend_height,
                               overlap_start:overlap_end]
            img2_region = img2[blend_y_start - img2_y_start:blend_y_start - img2_y_start + blend_height,
                               :overlap_width]
            min_h = min(img1_region.shape[0], img2_region.shape[0])
            min_w = min(img1_region.shape[1], img2_region.shape[1])
            if min_h > 0 and min_w > 0:
                img1_region = img1_region[:min_h, :min_w]
                img2_region = img2_region[:min_h, :min_w]
                alpha = alpha[:, :min_w, :]
                blended = (img1_region.astype(np.float32) * alpha +
                           img2_region.astype(np.float32) * (1 - alpha)).astype(np.uint8)
                stitched[blend_y_start:blend_y_start + min_h,
                         overlap_start:overlap_start + min_w] = blended

    non_overlap_start = w1
    if non_overlap_start < output_width:
        img2_src_x = actual_overlap
        copy_width = w2 - actual_overlap
        if copy_width > 0:
            stitched[img2_y_start:img2_y_start + h2,
                     non_overlap_start:non_overlap_start + copy_width] = \
                img2[:, img2_src_x:img2_src_x + copy_width]

    return stitched

# --- Sequential stitching (phase OR feature) ---
def stitch_multiple_images(image_paths, method='phase', add_y_offset=False,
                           edge_width=250, vertical_region=1000, vertical_offset=300, feature_method='sift'):
    if len(image_paths) < 2:
        return cv2.imread(image_paths[0]) if len(image_paths) == 1 else None

    result = stitch_two_images(image_paths[0], image_paths[1], method=method, add_y_offset=add_y_offset,
                               edge_width=edge_width, vertical_region=vertical_region, vertical_offset=vertical_offset,
                               feature_method=feature_method)
    for i in range(2, len(image_paths)):
        temp_path = "temp_intermediate.png"
        cv2.imwrite(temp_path, result)
        try:
            result = stitch_two_images(temp_path, image_paths[i], method=method, add_y_offset=add_y_offset,
                                       edge_width=edge_width, vertical_region=vertical_region, vertical_offset=vertical_offset,
                                       feature_method=feature_method)
        finally:
            if os.path.exists(temp_path):
                os.remove(temp_path)
    return result

# --- Sequential stitching (COMPARE): build both mosaics + print metrics ---
def stitch_multiple_images_compare(image_paths, add_y_offset=False,
                                   edge_width=250, vertical_region=1000, vertical_offset=300, feature_method='sift'):
    if len(image_paths) < 2:
        single = cv2.imread(image_paths[0]) if len(image_paths) == 1 else None
        return single, single, 0.0, 0.0, 0.0, None

    # Start both mosaics
    result_phase = stitch_two_images(image_paths[0], image_paths[1], method='phase', add_y_offset=add_y_offset,
                                     edge_width=edge_width, vertical_region=vertical_region, vertical_offset=vertical_offset)
    result_feat = stitch_two_images(image_paths[0], image_paths[1], method='feature', add_y_offset=add_y_offset,
                                    edge_width=edge_width, vertical_region=vertical_region, vertical_offset=vertical_offset,
                                    feature_method=feature_method)

    # Metrics arrays and tile position tracking
    dx_abs_list, dy_abs_list, euclid_list = [], [], []
    disagreements = []
    tile_positions = []
    
    # Get initial tile dimensions for position estimation
    first_img = cv2.imread(image_paths[0])
    tile_height, tile_width = first_img.shape[:2]
    
    # Step 1 metrics on the SAME raw tiles
    img_prev = cv2.imread(image_paths[0])
    img_curr = cv2.imread(image_paths[1])
    dx_p, dy_p = phase_correlation_alignment(img_prev, img_curr, edge_width=edge_width,
                                             vertical_region=vertical_region, vertical_offset=vertical_offset)
    dx_f, dy_f = feature_matching_alignment(img_prev, img_curr, edge_width=edge_width,
                                            vertical_region=vertical_region, vertical_offset=vertical_offset,
                                            feature_method=feature_method)

    dx_p  = -1*dx_p # align sign to dx_f
    dy_p  = -1*dy_p # align sign to dy_f
    dx_abs = abs(dx_p - dx_f)
    dy_abs = abs(dy_p - dy_f)
  
    euclid = np.sqrt((dx_p - dx_f)**2 + (dy_p - dy_f)**2)
    dx_abs_list.append(dx_abs); dy_abs_list.append(dy_abs); euclid_list.append(euclid)
    disagreements.append((dx_abs, dy_abs, euclid))
    
    # Estimate first tile position (approximately where the overlap occurs)
    tile_positions.append((tile_width - edge_width, 0, edge_width, tile_height))
    
    print(f"Step 1 disagreement ({feature_method.upper()}): dx_abs={dx_abs:.2f}, dy_abs={dy_abs:.2f}, euclid={euclid:.2f}")    
    print("dx_phase: ",dx_p)
    print("dx_feature: ",round(dx_f,2))
    print("dy_phase: ",dy_p)
    print("dy_feature: ",round(dy_f,2),"\n")

    # Continue both mosaics; metrics always on raw consecutive tiles (same pair basis)
    current_x_pos = tile_width
    for i in range(2, len(image_paths)):
        # Update mosaics
        temp_phase = "temp_phase.png"
        temp_feat = "temp_feat.png"
        cv2.imwrite(temp_phase, result_phase)
        cv2.imwrite(temp_feat, result_feat)
        try:
            result_phase = stitch_two_images(temp_phase, image_paths[i], method='phase', add_y_offset=add_y_offset,
                                             edge_width=edge_width, vertical_region=vertical_region, vertical_offset=vertical_offset)
            result_feat = stitch_two_images(temp_feat, image_paths[i], method='feature', add_y_offset=add_y_offset,
                                            edge_width=edge_width, vertical_region=vertical_region, vertical_offset=vertical_offset,
                                            feature_method=feature_method)
        finally:
            if os.path.exists(temp_phase): os.remove(temp_phase)
            if os.path.exists(temp_feat): os.remove(temp_feat)

        # Metrics on raw tiles (i-1 vs i), same basis
        img_prev = cv2.imread(image_paths[i-1])
        img_curr = cv2.imread(image_paths[i])
        dx_p, dy_p = phase_correlation_alignment(img_prev, img_curr, edge_width=edge_width,
                                                 vertical_region=vertical_region, vertical_offset=vertical_offset)
        dx_f, dy_f = feature_matching_alignment(img_prev, img_curr, edge_width=edge_width,
                                                vertical_region=vertical_region, vertical_offset=vertical_offset,
                                                feature_method=feature_method)
        
        dx_p  = -1*dx_p # align sign to dx_f
        dy_p  = -1*dy_p # align sign to dy_f
        dx_abs = abs(dx_p - dx_f)
        dy_abs = abs(dy_p - dy_f)
    
        euclid = np.sqrt((dx_p - dx_f)**2 + (dy_p - dy_f)**2)
        dx_abs_list.append(dx_abs); dy_abs_list.append(dy_abs); euclid_list.append(euclid)
        disagreements.append((dx_abs, dy_abs, euclid))
        
        # Estimate tile position (simplified - assumes tiles are added horizontally)
        tile_positions.append((current_x_pos - edge_width, 0, edge_width, tile_height))
        current_x_pos += (tile_width - edge_width)  # Approximate next position
        
        print(f"Step {i} disagreement ({feature_method.upper()}): dx_abs={dx_abs:.2f}, dy_abs={dy_abs:.2f}, euclid={euclid:.2f}")
        print("dx_phase: ",dx_p)
        print("dx_feature: ",round(dx_f,2))
        print("dy_phase: ",dy_p)
        print("dy_feature: ",round(dy_f,2),"\n")

    # Overall means
    mean_dx_abs = float(np.mean(dx_abs_list)) if dx_abs_list else 0.0
    mean_dy_abs = float(np.mean(dy_abs_list)) if dy_abs_list else 0.0
    mean_euclid = float(np.mean(euclid_list)) if euclid_list else 0.0
    print(f"\nOverall mean abs disagreement ({feature_method.upper()}): dx={mean_dx_abs:.2f}, dy={mean_dy_abs:.2f}, euclid={mean_euclid:.2f},\n")

    # Create distortion map
    if result_phase is not None:
        output_height, output_width = result_phase.shape[:2]
        distortion_map = create_distortion_map(disagreements, output_width, output_height, tile_positions)
    else:
        distortion_map = None

    return result_phase, result_feat, mean_dx_abs, mean_dy_abs, mean_euclid, distortion_map

# --- Main ---
year = '2025'
Session = 'Session02'
directory_path = 'C:/Users/jocu0013/Desktop/Oulanka/Scan_Raw/Oulanka2025_July/'
path_out = f'C:/Users/jocu0013/Desktop/blended_images/PhaseFeature/2025_02/Oulanka{year}_{Session}_'
pattern = '.tiff'

correlation_params = {
    'edge_width': 250,
    'vertical_region': 1000,
    'vertical_offset': 300,
}

method = 'compare'  # 'phase', 'feature', or 'compare'
feature_method = 'orb'  # 'sift', 'orb', 'akaze', 'brisk' (ignored if method is not 'feature' or 'compare')
add_y_offset = True  # keep your current sign choice

def main():
    imgs = list_files_with_pattern(directory_path, pattern)
    imgs = imgs[63:274]
    unique_names = list_unique_names_within_range(imgs, 73, 77)
    os.makedirs(os.path.dirname(path_out), exist_ok=True)
    print(f"Found {len(unique_names)} unique image sets")
    print(f"Method: {method}")
    if method in ['feature', 'compare']:
        print(f"Feature method: {feature_method.upper()}")

    for i, unique_name in enumerate(unique_names):
        print(f"\nProcessing {i+1}/{len(unique_names)}: {unique_name}")
        matching_images = elements_matching_pattern(imgs, str(unique_name))
        matching_images.sort()

        if len(matching_images) == 1:
            img = cv2.imread(matching_images[0])
            cv2.imwrite(path_out + str(unique_name) + ".png", img)
            print("  Single image - copied")
            continue

        try:
            if method == 'compare':
                stitched_phase, stitched_feat, mean_dx, mean_dy, mean_e, distortion_map = \
                    stitch_multiple_images_compare(matching_images, add_y_offset=add_y_offset, 
                                                   feature_method=feature_method, **correlation_params)
                cv2.imwrite(path_out + str(unique_name) + "_phase.png", stitched_phase)
                cv2.imwrite(path_out + str(unique_name) + f"_{feature_method}.png", stitched_feat)
                
                # Save distortion map if created
                if distortion_map is not None:
                    cv2.imwrite(path_out + str(unique_name) + "_distortion_map.png", distortion_map)
                    print(f"  Distortion map saved")
                
                print(f"  {len(matching_images)} images stitched (phase & {feature_method}). "
                      f"Mean |Δdx|={mean_dx:.2f}, |Δdy|={mean_dy:.2f}, euclid={mean_e:.2f}")
            else:
                stitched = stitch_multiple_images(matching_images, method=method, add_y_offset=add_y_offset, 
                                                  feature_method=feature_method, **correlation_params)
                suffix = f"_{feature_method}" if method == 'feature' else ""
                cv2.imwrite(path_out + str(unique_name) + suffix + ".png", stitched)
                method_name = f"{method} ({feature_method})" if method == 'feature' else method
                print(f"  {len(matching_images)} images stitched using method '{method_name}'")
        except Exception as e:
            print(f"  ERROR processing {unique_name}: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Found 36 unique image sets
# Method: compare
# Feature method: ORB
#
# Processing 1/36: T037
# Step 1 disagreement (ORB): dx_abs=0.72, dy_abs=2.08, euclid=2.20
# dx_phase:  109
# dx_feature:  109.72
# dy_phase:  11
# dy_feature:  13.08
#
# Step 2 disagreement (ORB): dx_abs=0.76, dy_abs=0.64, euclid=1.00
# dx_phase:  102
# dx_feature:  102.76
# dy_phase:  15
# dy_feature:  15.64
#
# Step 3 disagreement (ORB): dx_abs=0.03, dy_abs=1.12, euclid=1.12
# dx_phase:  99
# dx_feature:  98.97
# dy_phase:  12
# dy_feature:  13.12
#
# Step 4 disagreement (ORB): dx_abs=0.14, dy_abs=4.51, euclid=4.51
# dx_phase:  104
# dx_feature:  104.14
# dy_phase:  12
# dy_feature:  16.51
#
#
# Overall mean abs disagreement (ORB): dx=0.41, dy=2.09, euclid=2.21,
#
#   Distortion map saved
#   5 images stitched (phase & orb). Mean |Δdx|=0.41, |Δdy|=2.09, euclid=2.21
#
# Processing 2/36: T038
# Step 1 disagreement (ORB): dx_abs=0.60, dy_abs=2.22, euclid=2.30
# dx_phase:  117
# dx_feature:  116.4
# dy_phase:  11
# dy_feature:  8.78
#
# Step 2 disagreement (ORB): dx_abs=0.56, dy_abs=0.70, euclid=0.90
# dx_phase:  109
# dx_feature:  108.44
# dy_phase:  7
# dy_feature:  6.3
#
# Step 3 disagreement (ORB): dx_abs=0.12, dy_abs=0.99, euclid=1.00
# dx_phase:  102
# dx_feature:  102.12
# dy_phase:  10
# dy_feature:  9.01
#
# Step 4 disagreement (ORB): dx_abs=1.34, dy_abs=1.43, euclid=1.96
# dx_phase:  99
# dx_feature:  97.66
# dy_phase:  7
# dy_feature:  5.57
#
# Step 5 disagreement (ORB): dx_abs=0.20, dy_abs=0.82, euclid=0.84
# dx_phase:  103
# dx_feature:  103.2
# dy_phase:  6
# dy_feature:  5.18
#
#
# Overall mean abs disagreement (ORB): dx=0.56, dy=1.23, euclid=1.40,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=0.56, |Δdy|=1.23, euclid=1.40
#
# Processing 3/36: T039
# Step 1 disagreement (ORB): dx_abs=0.23, dy_abs=1.37, euclid=1.39
# dx_phase:  122
# dx_feature:  122.23
# dy_phase:  6
# dy_feature:  7.37
#
# Step 2 disagreement (ORB): dx_abs=0.05, dy_abs=0.81, euclid=0.81
# dx_phase:  111
# dx_feature:  111.05
# dy_phase:  8
# dy_feature:  8.81
#
# Step 3 disagreement (ORB): dx_abs=0.34, dy_abs=0.13, euclid=0.37
# dx_phase:  104
# dx_feature:  103.66
# dy_phase:  10
# dy_feature:  10.13
#
# Step 4 disagreement (ORB): dx_abs=0.31, dy_abs=1.39, euclid=1.42
# dx_phase:  98
# dx_feature:  97.69
# dy_phase:  13
# dy_feature:  14.39
#
# Step 5 disagreement (ORB): dx_abs=0.74, dy_abs=0.49, euclid=0.89
# dx_phase:  103
# dx_feature:  103.74
# dy_phase:  18
# dy_feature:  18.49
#
#
# Overall mean abs disagreement (ORB): dx=0.34, dy=0.84, euclid=0.98,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=0.34, |Δdy|=0.84, euclid=0.98
#
# Processing 4/36: T040
# Step 1 disagreement (ORB): dx_abs=122.00, dy_abs=1.00, euclid=122.00
# dx_phase:  122
# dx_feature:  0
# dy_phase:  1
# dy_feature:  0
#
# Step 2 disagreement (ORB): dx_abs=109.00, dy_abs=15.00, euclid=110.03
# dx_phase:  109
# dx_feature:  0
# dy_phase:  15
# dy_feature:  0
#
# Step 3 disagreement (ORB): dx_abs=1.67, dy_abs=0.05, euclid=1.67
# dx_phase:  103
# dx_feature:  101.33
# dy_phase:  9
# dy_feature:  8.95
#
# Step 4 disagreement (ORB): dx_abs=1.34, dy_abs=1.01, euclid=1.68
# dx_phase:  101
# dx_feature:  99.66
# dy_phase:  51
# dy_feature:  49.99
#
# Step 5 disagreement (ORB): dx_abs=0.39, dy_abs=2.10, euclid=2.14
# dx_phase:  103
# dx_feature:  103.39
# dy_phase:  13
# dy_feature:  15.1
#
#
# Overall mean abs disagreement (ORB): dx=46.88, dy=3.83, euclid=47.50,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=46.88, |Δdy|=3.83, euclid=47.50
#
# Processing 5/36: T041
# Step 1 disagreement (ORB): dx_abs=0.25, dy_abs=0.13, euclid=0.28
# dx_phase:  122
# dx_feature:  122.25
# dy_phase:  10
# dy_feature:  10.13
#
# Step 2 disagreement (ORB): dx_abs=0.41, dy_abs=0.86, euclid=0.95
# dx_phase:  110
# dx_feature:  109.59
# dy_phase:  20
# dy_feature:  19.14
#
# Step 3 disagreement (ORB): dx_abs=0.09, dy_abs=2.29, euclid=2.29
# dx_phase:  103
# dx_feature:  103.09
# dy_phase:  -43
# dy_feature:  -40.71
#
# Step 4 disagreement (ORB): dx_abs=0.80, dy_abs=0.68, euclid=1.05
# dx_phase:  99
# dx_feature:  98.2
# dy_phase:  57
# dy_feature:  56.32
#
# Step 5 disagreement (ORB): dx_abs=0.55, dy_abs=1.31, euclid=1.42
# dx_phase:  103
# dx_feature:  103.55
# dy_phase:  -45
# dy_feature:  -43.69
#
#
# Overall mean abs disagreement (ORB): dx=0.42, dy=1.05, euclid=1.20,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=0.42, |Δdy|=1.05, euclid=1.20
#
# Processing 6/36: T042
# Step 1 disagreement (ORB): dx_abs=0.51, dy_abs=0.96, euclid=1.08
# dx_phase:  124
# dx_feature:  124.51
# dy_phase:  7
# dy_feature:  7.96
#
# Step 2 disagreement (ORB): dx_abs=0.20, dy_abs=0.04, euclid=0.20
# dx_phase:  109
# dx_feature:  108.8
# dy_phase:  11
# dy_feature:  10.96
#
# Step 3 disagreement (ORB): dx_abs=0.13, dy_abs=0.70, euclid=0.72
# dx_phase:  103
# dx_feature:  102.87
# dy_phase:  10
# dy_feature:  10.7
#
# Step 4 disagreement (ORB): dx_abs=0.47, dy_abs=0.40, euclid=0.62
# dx_phase:  99
# dx_feature:  98.53
# dy_phase:  9
# dy_feature:  8.6
#
# Step 5 disagreement (ORB): dx_abs=0.09, dy_abs=0.68, euclid=0.69
# dx_phase:  104
# dx_feature:  104.09
# dy_phase:  9
# dy_feature:  8.32
#
#
# Overall mean abs disagreement (ORB): dx=0.28, dy=0.56, euclid=0.66,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=0.28, |Δdy|=0.56, euclid=0.66
#
# Processing 7/36: T043
# Step 1 disagreement (ORB): dx_abs=249.95, dy_abs=0.52, euclid=249.95
# dx_phase:  -112
# dx_feature:  137.95
# dy_phase:  11
# dy_feature:  11.52
#
# Step 2 disagreement (ORB): dx_abs=0.62, dy_abs=0.49, euclid=0.79
# dx_phase:  109
# dx_feature:  109.62
# dy_phase:  8
# dy_feature:  7.51
#
# Step 3 disagreement (ORB): dx_abs=0.53, dy_abs=0.10, euclid=0.54
# dx_phase:  104
# dx_feature:  103.47
# dy_phase:  9
# dy_feature:  8.9
#
# Step 4 disagreement (ORB): dx_abs=0.63, dy_abs=0.18, euclid=0.65
# dx_phase:  99
# dx_feature:  99.63
# dy_phase:  10
# dy_feature:  9.82
#
# Step 5 disagreement (ORB): dx_abs=1.00, dy_abs=1.27, euclid=1.62
# dx_phase:  103
# dx_feature:  102.0
# dy_phase:  9
# dy_feature:  7.73
#
#
# Overall mean abs disagreement (ORB): dx=50.55, dy=0.51, euclid=50.71,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=50.55, |Δdy|=0.51, euclid=50.71
#
# Processing 8/36: T044
# Step 1 disagreement (ORB): dx_abs=0.18, dy_abs=2.46, euclid=2.46
# dx_phase:  125
# dx_feature:  125.18
# dy_phase:  7
# dy_feature:  9.46
#
# Step 2 disagreement (ORB): dx_abs=0.61, dy_abs=6.04, euclid=6.07
# dx_phase:  109
# dx_feature:  109.61
# dy_phase:  6
# dy_feature:  12.04
#
# Step 3 disagreement (ORB): dx_abs=0.95, dy_abs=2.11, euclid=2.32
# dx_phase:  103
# dx_feature:  103.95
# dy_phase:  7
# dy_feature:  4.89
#
# Step 4 disagreement (ORB): dx_abs=1.41, dy_abs=2.49, euclid=2.86
# dx_phase:  99
# dx_feature:  100.41
# dy_phase:  8
# dy_feature:  5.51
#
# Step 5 disagreement (ORB): dx_abs=0.69, dy_abs=0.91, euclid=1.14
# dx_phase:  103
# dx_feature:  102.31
# dy_phase:  12
# dy_feature:  11.09
#
#
# Overall mean abs disagreement (ORB): dx=0.77, dy=2.80, euclid=2.97,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=0.77, |Δdy|=2.80, euclid=2.97
#
# Processing 9/36: T045
# Step 1 disagreement (ORB): dx_abs=0.07, dy_abs=1.07, euclid=1.08
# dx_phase:  119
# dx_feature:  119.07
# dy_phase:  -146
# dy_feature:  -144.93
#
# Step 2 disagreement (ORB): dx_abs=0.20, dy_abs=2.10, euclid=2.11
# dx_phase:  92
# dx_feature:  91.8
# dy_phase:  63
# dy_feature:  65.1
#
# Step 3 disagreement (ORB): dx_abs=2.02, dy_abs=4.30, euclid=4.75
# dx_phase:  98
# dx_feature:  95.98
# dy_phase:  17
# dy_feature:  12.7
#
# Step 4 disagreement (ORB): dx_abs=0.19, dy_abs=1.32, euclid=1.33
# dx_phase:  100
# dx_feature:  99.81
# dy_phase:  4
# dy_feature:  5.32
#
#
# Overall mean abs disagreement (ORB): dx=0.62, dy=2.20, euclid=2.32,
#
#   Distortion map saved
#   5 images stitched (phase & orb). Mean |Δdx|=0.62, |Δdy|=2.20, euclid=2.32
#
# Processing 10/36: T046
# Step 1 disagreement (ORB): dx_abs=249.61, dy_abs=2.33, euclid=249.62
# dx_phase:  -117
# dx_feature:  132.61
# dy_phase:  -19
# dy_feature:  -16.67
#
# Step 2 disagreement (ORB): dx_abs=0.03, dy_abs=1.92, euclid=1.92
# dx_phase:  109
# dx_feature:  109.03
# dy_phase:  11
# dy_feature:  12.92
#
# Step 3 disagreement (ORB): dx_abs=0.37, dy_abs=0.10, euclid=0.38
# dx_phase:  103
# dx_feature:  102.63
# dy_phase:  -1
# dy_feature:  -0.9
#
# Step 4 disagreement (ORB): dx_abs=0.06, dy_abs=0.90, euclid=0.90
# dx_phase:  99
# dx_feature:  99.06
# dy_phase:  7
# dy_feature:  7.9
#
# Step 5 disagreement (ORB): dx_abs=1.11, dy_abs=0.88, euclid=1.42
# dx_phase:  104
# dx_feature:  102.89
# dy_phase:  13
# dy_feature:  13.88
#
#
# Overall mean abs disagreement (ORB): dx=50.23, dy=1.23, euclid=50.85,
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=50.23, |Δdy|=1.23, euclid=50.85
#
# Processing 11/36: T047
# Step 1 disagreement (ORB): dx_abs=0.33, dy_abs=0.39, euclid=0.51
# dx_phase:  124
# dx_feature:  123.67
# dy_phase:  -2
# dy_feature:  -1.61
#
# Step 2 disagreement (ORB): dx_abs=0.00, dy_abs=2.24, euclid=2.24
# dx_phase:  109
# dx_feature:  109.0
# dy_phase:  6
# dy_feature:  8.24
#
# Step 3 disagreement (ORB): dx_abs=0.34, dy_abs=0.11, euclid=0.36
# dx_phase:  103
# dx_feature:  102.66
# dy_phase:  3
# dy_feature:  3.11
#
# Step 4 disagreement (ORB): dx_abs=0.61, dy_abs=0.03, euclid=0.61
# dx_phase:  99
# dx_feature:  99.61
# dy_phase:  4
# dy_feature:  3.97
#
# Step 5 disagreement (ORB): dx_abs=0.65, dy_abs=1.21, euclid=1.37
# dx_phase:  103
# dx_feature:  102.35
# dy_phase:  5
# dy_feature:  6.21
#
#
# Overall mean abs disagreement (ORB): dx=0.39, dy=0.80, euclid=1.02,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=0.39, |Δdy|=0.80, euclid=1.02
#
# Processing 12/36: T048
# Step 1 disagreement (ORB): dx_abs=249.28, dy_abs=4.54, euclid=249.32
# dx_phase:  -124
# dx_feature:  125.28
# dy_phase:  -3
# dy_feature:  1.54
#
# Step 2 disagreement (ORB): dx_abs=0.76, dy_abs=0.29, euclid=0.82
# dx_phase:  109
# dx_feature:  109.76
# dy_phase:  7
# dy_feature:  7.29
#
# Step 3 disagreement (ORB): dx_abs=0.43, dy_abs=2.06, euclid=2.10
# dx_phase:  103
# dx_feature:  102.57
# dy_phase:  2
# dy_feature:  4.06
#
# Step 4 disagreement (ORB): dx_abs=0.68, dy_abs=1.44, euclid=1.59
# dx_phase:  99
# dx_feature:  98.32
# dy_phase:  4
# dy_feature:  5.44
#
# Step 5 disagreement (ORB): dx_abs=0.01, dy_abs=0.10, euclid=0.10
# dx_phase:  103
# dx_feature:  102.99
# dy_phase:  10
# dy_feature:  10.1
#
#
# Overall mean abs disagreement (ORB): dx=50.23, dy=1.69, euclid=50.79,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=50.23, |Δdy|=1.69, euclid=50.79
#
# Processing 13/36: T049
# Step 1 disagreement (ORB): dx_abs=250.93, dy_abs=1.65, euclid=250.93
# dx_phase:  -119
# dx_feature:  131.93
# dy_phase:  12
# dy_feature:  13.65
#
# Step 2 disagreement (ORB): dx_abs=0.45, dy_abs=1.13, euclid=1.22
# dx_phase:  109
# dx_feature:  108.55
# dy_phase:  11
# dy_feature:  12.13
#
# Step 3 disagreement (ORB): dx_abs=0.03, dy_abs=0.34, euclid=0.34
# dx_phase:  104
# dx_feature:  103.97
# dy_phase:  12
# dy_feature:  12.34
#
# Step 4 disagreement (ORB): dx_abs=0.52, dy_abs=0.53, euclid=0.74
# dx_phase:  99
# dx_feature:  99.52
# dy_phase:  14
# dy_feature:  14.53
#
# Step 5 disagreement (ORB): dx_abs=0.21, dy_abs=0.93, euclid=0.95
# dx_phase:  104
# dx_feature:  104.21
# dy_phase:  17
# dy_feature:  17.93
#
#
# Overall mean abs disagreement (ORB): dx=50.43, dy=0.91, euclid=50.84,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=50.43, |Δdy|=0.91, euclid=50.84
#
# Processing 14/36: T050
# Step 1 disagreement (ORB): dx_abs=250.05, dy_abs=0.90, euclid=250.05
# dx_phase:  -116
# dx_feature:  134.05
# dy_phase:  9
# dy_feature:  9.9
#
# Step 2 disagreement (ORB): dx_abs=0.15, dy_abs=1.27, euclid=1.28
# dx_phase:  109
# dx_feature:  109.15
# dy_phase:  16
# dy_feature:  17.27
#
# Step 3 disagreement (ORB): dx_abs=0.02, dy_abs=0.70, euclid=0.70
# dx_phase:  103
# dx_feature:  102.98
# dy_phase:  10
# dy_feature:  10.7
#
# Step 4 disagreement (ORB): dx_abs=0.22, dy_abs=0.71, euclid=0.74
# dx_phase:  99
# dx_feature:  98.78
# dy_phase:  13
# dy_feature:  13.71
#
# Step 5 disagreement (ORB): dx_abs=0.30, dy_abs=0.64, euclid=0.71
# dx_phase:  103
# dx_feature:  103.3
# dy_phase:  13
# dy_feature:  13.64
#
#
# Overall mean abs disagreement (ORB): dx=50.15, dy=0.84, euclid=50.69,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=50.15, |Δdy|=0.84, euclid=50.69
#
# Processing 15/36: T051
# Step 1 disagreement (ORB): dx_abs=250.62, dy_abs=0.54, euclid=250.62
# dx_phase:  -121
# dx_feature:  129.62
# dy_phase:  19
# dy_feature:  19.54
#
# Step 2 disagreement (ORB): dx_abs=0.70, dy_abs=0.34, euclid=0.78
# dx_phase:  111
# dx_feature:  111.7
# dy_phase:  9
# dy_feature:  9.34
#
# Step 3 disagreement (ORB): dx_abs=0.39, dy_abs=0.20, euclid=0.44
# dx_phase:  104
# dx_feature:  104.39
# dy_phase:  12
# dy_feature:  12.2
#
# Step 4 disagreement (ORB): dx_abs=0.16, dy_abs=0.02, euclid=0.16
# dx_phase:  102
# dx_feature:  101.84
# dy_phase:  12
# dy_feature:  12.02
#
# Step 5 disagreement (ORB): dx_abs=0.24, dy_abs=0.76, euclid=0.80
# dx_phase:  104
# dx_feature:  104.24
# dy_phase:  13
# dy_feature:  13.76
#
#
# Overall mean abs disagreement (ORB): dx=50.42, dy=0.37, euclid=50.56,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=50.42, |Δdy|=0.37, euclid=50.56
#
# Processing 16/36: T052
# Step 1 disagreement (ORB): dx_abs=1.07, dy_abs=1.72, euclid=2.03
# dx_phase:  125
# dx_feature:  123.93
# dy_phase:  -3
# dy_feature:  -4.72
#
# Step 2 disagreement (ORB): dx_abs=0.11, dy_abs=0.52, euclid=0.53
# dx_phase:  106
# dx_feature:  105.89
# dy_phase:  11
# dy_feature:  11.52
#
# Step 3 disagreement (ORB): dx_abs=0.01, dy_abs=0.87, euclid=0.87
# dx_phase:  103
# dx_feature:  103.01
# dy_phase:  9
# dy_feature:  9.87
#
# Step 4 disagreement (ORB): dx_abs=0.59, dy_abs=0.65, euclid=0.88
# dx_phase:  100
# dx_feature:  99.41
# dy_phase:  13
# dy_feature:  13.65
#
# Step 5 disagreement (ORB): dx_abs=0.86, dy_abs=0.27, euclid=0.91
# dx_phase:  103
# dx_feature:  103.86
# dy_phase:  10
# dy_feature:  10.27
#
#
# Overall mean abs disagreement (ORB): dx=0.53, dy=0.81, euclid=1.04,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=0.53, |Δdy|=0.81, euclid=1.04
#
# Processing 17/36: T053
# Step 1 disagreement (ORB): dx_abs=0.37, dy_abs=0.77, euclid=0.85
# dx_phase:  124
# dx_feature:  123.63
# dy_phase:  -5
# dy_feature:  -4.23
#
# Step 2 disagreement (ORB): dx_abs=0.30, dy_abs=0.79, euclid=0.85
# dx_phase:  110
# dx_feature:  109.7
# dy_phase:  10
# dy_feature:  10.79
#
# Step 3 disagreement (ORB): dx_abs=0.09, dy_abs=1.09, euclid=1.09
# dx_phase:  104
# dx_feature:  104.09
# dy_phase:  31
# dy_feature:  32.09
#
# Step 4 disagreement (ORB): dx_abs=0.05, dy_abs=1.45, euclid=1.45
# dx_phase:  99
# dx_feature:  98.95
# dy_phase:  11
# dy_feature:  12.45
#
# Step 5 disagreement (ORB): dx_abs=0.42, dy_abs=4.34, euclid=4.36
# dx_phase:  104
# dx_feature:  104.42
# dy_phase:  15
# dy_feature:  19.34
#
#
# Overall mean abs disagreement (ORB): dx=0.25, dy=1.69, euclid=1.72,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=0.25, |Δdy|=1.69, euclid=1.72
#
# Processing 18/36: T054
# Step 1 disagreement (ORB): dx_abs=250.78, dy_abs=1.50, euclid=250.78
# dx_phase:  -121
# dx_feature:  129.78
# dy_phase:  17
# dy_feature:  18.5
#
# Step 2 disagreement (ORB): dx_abs=0.43, dy_abs=0.67, euclid=0.79
# dx_phase:  109
# dx_feature:  108.57
# dy_phase:  10
# dy_feature:  10.67
#
# Step 3 disagreement (ORB): dx_abs=0.36, dy_abs=0.41, euclid=0.54
# dx_phase:  103
# dx_feature:  102.64
# dy_phase:  9
# dy_feature:  9.41
#
# Step 4 disagreement (ORB): dx_abs=0.36, dy_abs=1.93, euclid=1.97
# dx_phase:  99
# dx_feature:  98.64
# dy_phase:  10
# dy_feature:  11.93
#
# Step 5 disagreement (ORB): dx_abs=0.67, dy_abs=1.77, euclid=1.90
# dx_phase:  104
# dx_feature:  103.33
# dy_phase:  10
# dy_feature:  11.77
#
#
# Overall mean abs disagreement (ORB): dx=50.52, dy=1.26, euclid=51.20,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=50.52, |Δdy|=1.26, euclid=51.20
#
# Processing 19/36: T055
# Step 1 disagreement (ORB): dx_abs=250.18, dy_abs=0.62, euclid=250.18
# dx_phase:  -121
# dx_feature:  129.18
# dy_phase:  16
# dy_feature:  16.62
#
# Step 2 disagreement (ORB): dx_abs=0.45, dy_abs=0.24, euclid=0.51
# dx_phase:  109
# dx_feature:  109.45
# dy_phase:  13
# dy_feature:  13.24
#
# Step 3 disagreement (ORB): dx_abs=0.07, dy_abs=0.76, euclid=0.76
# dx_phase:  104
# dx_feature:  104.07
# dy_phase:  15
# dy_feature:  15.76
#
# Step 4 disagreement (ORB): dx_abs=0.53, dy_abs=0.24, euclid=0.58
# dx_phase:  99
# dx_feature:  98.47
# dy_phase:  10
# dy_feature:  9.76
#
# Step 5 disagreement (ORB): dx_abs=0.43, dy_abs=0.00, euclid=0.43
# dx_phase:  104
# dx_feature:  103.57
# dy_phase:  12
# dy_feature:  12.0
#
#
# Overall mean abs disagreement (ORB): dx=50.33, dy=0.37, euclid=50.49,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=50.33, |Δdy|=0.37, euclid=50.49
#
# Processing 20/36: T056
# Step 1 disagreement (ORB): dx_abs=250.41, dy_abs=1.73, euclid=250.41
# dx_phase:  -118
# dx_feature:  132.41
# dy_phase:  16
# dy_feature:  17.73
#
# Step 2 disagreement (ORB): dx_abs=0.77, dy_abs=1.48, euclid=1.67
# dx_phase:  109
# dx_feature:  109.77
# dy_phase:  11
# dy_feature:  12.48
# Step 3 disagreement (ORB): dx_abs=0.49, dy_abs=0.57, euclid=0.75
# dx_phase:  104
# dx_feature:  104.49
# dy_phase:  8
# dy_feature:  8.57
#
# Step 4 disagreement (ORB): dx_abs=0.39, dy_abs=1.93, euclid=1.96
# dx_phase:  100
# dx_feature:  100.39
# dy_phase:  11
# dy_feature:  12.93
#
# Step 5 disagreement (ORB): dx_abs=0.45, dy_abs=0.59, euclid=0.75
# dx_phase:  104
# dx_feature:  104.45
# dy_phase:  10
# dy_feature:  10.59
#
#
# Overall mean abs disagreement (ORB): dx=50.50, dy=1.26, euclid=51.11,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=50.50, |Δdy|=1.26, euclid=51.11
#
# Processing 21/36: T057
# Step 1 disagreement (ORB): dx_abs=249.92, dy_abs=0.05, euclid=249.92
# dx_phase:  -122
# dx_feature:  127.92
# dy_phase:  -3
# dy_feature:  -2.95
#
# Step 2 disagreement (ORB): dx_abs=0.23, dy_abs=0.23, euclid=0.33
# dx_phase:  109
# dx_feature:  109.23
# dy_phase:  12
# dy_feature:  11.77
#
# Step 3 disagreement (ORB): dx_abs=0.28, dy_abs=0.58, euclid=0.65
# dx_phase:  93
# dx_feature:  93.28
# dy_phase:  120
# dy_feature:  120.58
#
# Step 4 disagreement (ORB): dx_abs=0.25, dy_abs=0.43, euclid=0.50
# dx_phase:  99
# dx_feature:  98.75
# dy_phase:  10
# dy_feature:  9.57
#
# Step 5 disagreement (ORB): dx_abs=0.08, dy_abs=0.01, euclid=0.08
# dx_phase:  103
# dx_feature:  103.08
# dy_phase:  8
# dy_feature:  8.01
#
#
# Overall mean abs disagreement (ORB): dx=50.16, dy=0.26, euclid=50.30,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=50.16, |Δdy|=0.26, euclid=50.30
#
# Processing 22/36: T058
# Step 1 disagreement (ORB): dx_abs=0.85, dy_abs=0.48, euclid=0.97
# dx_phase:  110
# dx_feature:  109.15
# dy_phase:  12
# dy_feature:  12.48
#
# Step 2 disagreement (ORB): dx_abs=1.01, dy_abs=0.08, euclid=1.02
# dx_phase:  103
# dx_feature:  104.01
# dy_phase:  13
# dy_feature:  12.92
#
# Step 3 disagreement (ORB): dx_abs=1.29, dy_abs=1.32, euclid=1.85
# dx_phase:  99
# dx_feature:  100.29
# dy_phase:  14
# dy_feature:  12.68
#
# Step 4 disagreement (ORB): dx_abs=0.81, dy_abs=2.14, euclid=2.29
# dx_phase:  104
# dx_feature:  104.81
# dy_phase:  13
# dy_feature:  15.14
#
#
# Overall mean abs disagreement (ORB): dx=0.99, dy=1.01, euclid=1.53,
#
#   Distortion map saved
#   5 images stitched (phase & orb). Mean |Δdx|=0.99, |Δdy|=1.01, euclid=1.53
#
# Processing 23/36: T059
# Step 1 disagreement (ORB): dx_abs=0.17, dy_abs=0.52, euclid=0.55
# dx_phase:  105
# dx_feature:  104.83
# dy_phase:  13
# dy_feature:  12.48
#
# Step 2 disagreement (ORB): dx_abs=0.12, dy_abs=1.38, euclid=1.39
# dx_phase:  100
# dx_feature:  99.88
# dy_phase:  13
# dy_feature:  11.62
#
# Step 3 disagreement (ORB): dx_abs=0.54, dy_abs=1.65, euclid=1.74
# dx_phase:  103
# dx_feature:  103.54
# dy_phase:  14
# dy_feature:  12.35
#
#
# Overall mean abs disagreement (ORB): dx=0.28, dy=1.19, euclid=1.23,
#
#   Distortion map saved
#   4 images stitched (phase & orb). Mean |Δdx|=0.28, |Δdy|=1.19, euclid=1.23
#
# Processing 24/36: T060
# Step 1 disagreement (ORB): dx_abs=0.40, dy_abs=1.25, euclid=1.31
# dx_phase:  125
# dx_feature:  124.6
# dy_phase:  11
# dy_feature:  12.25
#
# Step 2 disagreement (ORB): dx_abs=0.76, dy_abs=0.41, euclid=0.86
# dx_phase:  109
# dx_feature:  108.24
# dy_phase:  14
# dy_feature:  13.59
#
# Step 3 disagreement (ORB): dx_abs=0.13, dy_abs=1.36, euclid=1.36
# dx_phase:  103
# dx_feature:  102.87
# dy_phase:  13
# dy_feature:  11.64
#
# Step 4 disagreement (ORB): dx_abs=0.24, dy_abs=2.55, euclid=2.56
# dx_phase:  98
# dx_feature:  98.24
# dy_phase:  10
# dy_feature:  7.45
#
# Step 5 disagreement (ORB): dx_abs=0.04, dy_abs=2.08, euclid=2.08
# dx_phase:  103
# dx_feature:  102.96
# dy_phase:  12
# dy_feature:  9.92
#
#
# Overall mean abs disagreement (ORB): dx=0.31, dy=1.53, euclid=1.64,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=0.31, |Δdy|=1.53, euclid=1.64
#
# Processing 25/36: T061
# Step 1 disagreement (ORB): dx_abs=249.99, dy_abs=0.05, euclid=249.99
# dx_phase:  -121
# dx_feature:  128.99
# dy_phase:  13
# dy_feature:  13.05
#
# Step 2 disagreement (ORB): dx_abs=0.54, dy_abs=1.34, euclid=1.45
# dx_phase:  109
# dx_feature:  108.46
# dy_phase:  9
# dy_feature:  7.66
#
# Step 3 disagreement (ORB): dx_abs=0.16, dy_abs=0.68, euclid=0.70
# dx_phase:  106
# dx_feature:  105.84
# dy_phase:  11
# dy_feature:  10.32
#
# Step 4 disagreement (ORB): dx_abs=0.87, dy_abs=0.10, euclid=0.87
# dx_phase:  101
# dx_feature:  100.13
# dy_phase:  10
# dy_feature:  9.9
#
# Step 5 disagreement (ORB): dx_abs=1.03, dy_abs=0.97, euclid=1.42
# dx_phase:  98
# dx_feature:  96.97
# dy_phase:  7
# dy_feature:  6.03
#
#
# Overall mean abs disagreement (ORB): dx=50.52, dy=0.63, euclid=50.89,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=50.52, |Δdy|=0.63, euclid=50.89
#
# Processing 26/36: T062
# Step 1 disagreement (ORB): dx_abs=248.72, dy_abs=0.02, euclid=248.72
# dx_phase:  -122
# dx_feature:  126.72
# dy_phase:  12
# dy_feature:  11.98
#
# Step 2 disagreement (ORB): dx_abs=0.49, dy_abs=0.91, euclid=1.03
# dx_phase:  109
# dx_feature:  108.51
# dy_phase:  13
# dy_feature:  12.09
#
# Step 3 disagreement (ORB): dx_abs=0.94, dy_abs=0.88, euclid=1.29
# dx_phase:  102
# dx_feature:  101.06
# dy_phase:  11
# dy_feature:  10.12
#
# Step 4 disagreement (ORB): dx_abs=0.78, dy_abs=0.06, euclid=0.78
# dx_phase:  100
# dx_feature:  99.22
# dy_phase:  5
# dy_feature:  4.94
#
# Step 5 disagreement (ORB): dx_abs=0.15, dy_abs=0.14, euclid=0.21
# dx_phase:  103
# dx_feature:  102.85
# dy_phase:  10
# dy_feature:  9.86
#
#
# Overall mean abs disagreement (ORB): dx=50.22, dy=0.40, euclid=50.41,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=50.22, |Δdy|=0.40, euclid=50.41
#
# Processing 27/36: T063
# Step 1 disagreement (ORB): dx_abs=250.39, dy_abs=1.60, euclid=250.40
# dx_phase:  -113
# dx_feature:  137.39
# dy_phase:  2
# dy_feature:  0.4
#
# Step 2 disagreement (ORB): dx_abs=0.13, dy_abs=0.21, euclid=0.24
# dx_phase:  109
# dx_feature:  108.87
# dy_phase:  13
# dy_feature:  12.79
#
# Step 3 disagreement (ORB): dx_abs=1.56, dy_abs=0.42, euclid=1.62
# dx_phase:  104
# dx_feature:  105.56
# dy_phase:  16
# dy_feature:  16.42
#
# Step 4 disagreement (ORB): dx_abs=1.72, dy_abs=0.80, euclid=1.90
# dx_phase:  99
# dx_feature:  100.72
# dy_phase:  12
# dy_feature:  11.2
#
# Step 5 disagreement (ORB): dx_abs=1.24, dy_abs=0.11, euclid=1.25
# dx_phase:  104
# dx_feature:  105.24
# dy_phase:  11
# dy_feature:  10.89
#
#
# Overall mean abs disagreement (ORB): dx=51.01, dy=0.63, euclid=51.08,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=51.01, |Δdy|=0.63, euclid=51.08
#
# Processing 28/36: T064
# Step 1 disagreement (ORB): dx_abs=1.00, dy_abs=0.96, euclid=1.38
# dx_phase:  120
# dx_feature:  121.0
# dy_phase:  -6
# dy_feature:  -5.04
#
# Step 2 disagreement (ORB): dx_abs=0.29, dy_abs=0.22, euclid=0.36
# dx_phase:  110
# dx_feature:  110.29
# dy_phase:  12
# dy_feature:  11.78
#
# Step 3 disagreement (ORB): dx_abs=0.06, dy_abs=0.08, euclid=0.10
# dx_phase:  104
# dx_feature:  104.06
# dy_phase:  15
# dy_feature:  14.92
#
# Step 4 disagreement (ORB): dx_abs=0.22, dy_abs=0.23, euclid=0.32
# dx_phase:  100
# dx_feature:  100.22
# dy_phase:  11
# dy_feature:  11.23
#
# Step 5 disagreement (ORB): dx_abs=0.28, dy_abs=0.12, euclid=0.31
# dx_phase:  103
# dx_feature:  103.28
# dy_phase:  7
# dy_feature:  6.88
#
#
# Overall mean abs disagreement (ORB): dx=0.37, dy=0.32, euclid=0.49,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=0.37, |Δdy|=0.32, euclid=0.49
#
# Processing 29/36: T065
# Step 1 disagreement (ORB): dx_abs=0.76, dy_abs=7.73, euclid=7.77
# dx_phase:  119
# dx_feature:  119.76
# dy_phase:  27
# dy_feature:  34.73
#
# Step 2 disagreement (ORB): dx_abs=0.66, dy_abs=0.85, euclid=1.07
# dx_phase:  109
# dx_feature:  109.66
# dy_phase:  -21
# dy_feature:  -20.15
#
# Step 3 disagreement (ORB): dx_abs=0.32, dy_abs=0.68, euclid=0.76
# dx_phase:  104
# dx_feature:  104.32
# dy_phase:  13
# dy_feature:  13.68
#
# Step 4 disagreement (ORB): dx_abs=0.32, dy_abs=1.02, euclid=1.07
# dx_phase:  99
# dx_feature:  99.32
# dy_phase:  14
# dy_feature:  15.02
#
# Step 5 disagreement (ORB): dx_abs=0.30, dy_abs=0.89, euclid=0.94
# dx_phase:  102
# dx_feature:  101.7
# dy_phase:  13
# dy_feature:  13.89
#
#
# Overall mean abs disagreement (ORB): dx=0.47, dy=2.24, euclid=2.32,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=0.47, |Δdy|=2.24, euclid=2.32
#
# Processing 30/36: T066
# Step 1 disagreement (ORB): dx_abs=250.46, dy_abs=1.17, euclid=250.46
# dx_phase:  -119
# dx_feature:  131.46
# dy_phase:  3
# dy_feature:  4.17
#
# Step 2 disagreement (ORB): dx_abs=0.77, dy_abs=3.48, euclid=3.57
# dx_phase:  108
# dx_feature:  108.77
# dy_phase:  5
# dy_feature:  8.48
# Step 3 disagreement (ORB): dx_abs=0.34, dy_abs=2.09, euclid=2.12
# dx_phase:  102
# dx_feature:  102.34
# dy_phase:  13
# dy_feature:  15.09
#
# Step 4 disagreement (ORB): dx_abs=0.29, dy_abs=1.08, euclid=1.11
# dx_phase:  100
# dx_feature:  100.29
# dy_phase:  8
# dy_feature:  9.08
#
# Step 5 disagreement (ORB): dx_abs=0.30, dy_abs=1.79, euclid=1.81
# dx_phase:  103
# dx_feature:  103.3
# dy_phase:  11
# dy_feature:  12.79
#
#
# Overall mean abs disagreement (ORB): dx=50.43, dy=1.92, euclid=51.81,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=50.43, |Δdy|=1.92, euclid=51.81
#
# Processing 31/36: T067
# Step 1 disagreement (ORB): dx_abs=249.85, dy_abs=1.40, euclid=249.86
# dx_phase:  -111
# dx_feature:  138.85
# dy_phase:  8
# dy_feature:  9.4
#
# Step 2 disagreement (ORB): dx_abs=0.45, dy_abs=1.88, euclid=1.93
# dx_phase:  109
# dx_feature:  109.45
# dy_phase:  8
# dy_feature:  9.88
#
# Step 3 disagreement (ORB): dx_abs=0.41, dy_abs=1.71, euclid=1.75
# dx_phase:  104
# dx_feature:  104.41
# dy_phase:  10
# dy_feature:  11.71
#
# Step 4 disagreement (ORB): dx_abs=0.05, dy_abs=0.78, euclid=0.79
# dx_phase:  102
# dx_feature:  102.05
# dy_phase:  12
# dy_feature:  12.78
#
# Step 5 disagreement (ORB): dx_abs=0.66, dy_abs=1.61, euclid=1.74
# dx_phase:  107
# dx_feature:  107.66
# dy_phase:  14
# dy_feature:  15.61
#
#
# Overall mean abs disagreement (ORB): dx=50.28, dy=1.48, euclid=51.21,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=50.28, |Δdy|=1.48, euclid=51.21
#
# Processing 32/36: T068
# Step 1 disagreement (ORB): dx_abs=250.49, dy_abs=1.30, euclid=250.49
# dx_phase:  -106
# dx_feature:  144.49
# dy_phase:  -37
# dy_feature:  -35.7
#
# Step 2 disagreement (ORB): dx_abs=0.41, dy_abs=0.94, euclid=1.02
# dx_phase:  107
# dx_feature:  107.41
# dy_phase:  12
# dy_feature:  12.94
#
# Step 3 disagreement (ORB): dx_abs=1.17, dy_abs=1.65, euclid=2.03
# dx_phase:  106
# dx_feature:  104.83
# dy_phase:  -130
# dy_feature:  -128.35
#
# Step 4 disagreement (ORB): dx_abs=0.23, dy_abs=0.99, euclid=1.02
# dx_phase:  96
# dx_feature:  96.23
# dy_phase:  130
# dy_feature:  130.99
#
# Step 5 disagreement (ORB): dx_abs=0.60, dy_abs=0.16, euclid=0.62
# dx_phase:  104
# dx_feature:  104.6
# dy_phase:  7
# dy_feature:  7.16
#
#
# Overall mean abs disagreement (ORB): dx=50.58, dy=1.01, euclid=51.04,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=50.58, |Δdy|=1.01, euclid=51.04
#
# Processing 33/36: T069
# Step 1 disagreement (ORB): dx_abs=250.42, dy_abs=1.01, euclid=250.43
# dx_phase:  -119
# dx_feature:  131.42
# dy_phase:  4
# dy_feature:  5.01
#
# Step 2 disagreement (ORB): dx_abs=0.23, dy_abs=1.11, euclid=1.13
# dx_phase:  109
# dx_feature:  109.23
# dy_phase:  14
# dy_feature:  15.11
#
# Step 3 disagreement (ORB): dx_abs=1.04, dy_abs=1.05, euclid=1.47
# dx_phase:  102
# dx_feature:  103.04
# dy_phase:  16
# dy_feature:  17.05
#
# Step 4 disagreement (ORB): dx_abs=0.49, dy_abs=1.71, euclid=1.78
# dx_phase:  99
# dx_feature:  99.49
# dy_phase:  10
# dy_feature:  11.71
#
# Step 5 disagreement (ORB): dx_abs=0.94, dy_abs=0.99, euclid=1.36
# dx_phase:  103
# dx_feature:  103.94
# dy_phase:  13
# dy_feature:  13.99
#
#
# Overall mean abs disagreement (ORB): dx=50.62, dy=1.17, euclid=51.23,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=50.62, |Δdy|=1.17, euclid=51.23
#
# Processing 34/36: T070
# Step 1 disagreement (ORB): dx_abs=1.57, dy_abs=0.39, euclid=1.62
# dx_phase:  122
# dx_feature:  123.57
# dy_phase:  21
# dy_feature:  21.39
#
# Step 2 disagreement (ORB): dx_abs=0.11, dy_abs=0.94, euclid=0.95
# dx_phase:  109
# dx_feature:  108.89
# dy_phase:  13
# dy_feature:  13.94
#
# Step 3 disagreement (ORB): dx_abs=0.29, dy_abs=2.75, euclid=2.76
# dx_phase:  103
# dx_feature:  102.71
# dy_phase:  12
# dy_feature:  14.75
#
# Step 4 disagreement (ORB): dx_abs=0.43, dy_abs=3.62, euclid=3.65
# dx_phase:  99
# dx_feature:  98.57
# dy_phase:  10
# dy_feature:  13.62
#
# Step 5 disagreement (ORB): dx_abs=1.08, dy_abs=1.84, euclid=2.14
# dx_phase:  102
# dx_feature:  103.08
# dy_phase:  11
# dy_feature:  12.84
#
#
# Overall mean abs disagreement (ORB): dx=0.70, dy=1.91, euclid=2.22,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=0.70, |Δdy|=1.91, euclid=2.22
#
# Processing 35/36: T071
# Step 1 disagreement (ORB): dx_abs=250.31, dy_abs=1.98, euclid=250.31
# dx_phase:  -120
# dx_feature:  130.31
# dy_phase:  -45
# dy_feature:  -43.02
#
# Step 2 disagreement (ORB): dx_abs=0.02, dy_abs=5.52, euclid=5.52
# dx_phase:  109
# dx_feature:  109.02
# dy_phase:  6
# dy_feature:  11.52
#
# Step 3 disagreement (ORB): dx_abs=0.49, dy_abs=4.95, euclid=4.97
# dx_phase:  103
# dx_feature:  103.49
# dy_phase:  5
# dy_feature:  9.95
#
# Step 4 disagreement (ORB): dx_abs=0.23, dy_abs=6.34, euclid=6.35
# dx_phase:  99
# dx_feature:  98.77
# dy_phase:  7
# dy_feature:  13.34
#
# Step 5 disagreement (ORB): dx_abs=0.12, dy_abs=5.95, euclid=5.95
# dx_phase:  104
# dx_feature:  103.88
# dy_phase:  -3
# dy_feature:  2.95
#
#
# Overall mean abs disagreement (ORB): dx=50.23, dy=4.95, euclid=54.62,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=50.23, |Δdy|=4.95, euclid=54.62
#
# Processing 36/36: T072
# Step 1 disagreement (ORB): dx_abs=0.54, dy_abs=0.74, euclid=0.92
# dx_phase:  115
# dx_feature:  115.54
# dy_phase:  19
# dy_feature:  19.74
#
# Step 2 disagreement (ORB): dx_abs=0.58, dy_abs=1.68, euclid=1.77
# dx_phase:  109
# dx_feature:  109.58
# dy_phase:  6
# dy_feature:  7.68
#
# Step 3 disagreement (ORB): dx_abs=0.78, dy_abs=2.84, euclid=2.94
# dx_phase:  103
# dx_feature:  103.78
# dy_phase:  10
# dy_feature:  12.84
#
# Step 4 disagreement (ORB): dx_abs=1.28, dy_abs=0.11, euclid=1.28
# dx_phase:  100
# dx_feature:  101.28
# dy_phase:  8
# dy_feature:  8.11
#
# Step 5 disagreement (ORB): dx_abs=0.53, dy_abs=1.46, euclid=1.56
# dx_phase:  104
# dx_feature:  104.53
# dy_phase:  11
# dy_feature:  12.46
#
#
# Overall mean abs disagreement (ORB): dx=0.74, dy=1.37, euclid=1.69,
#
#   Distortion map saved
#   6 images stitched (phase & orb). Mean |Δdx|=0.74, |Δdy|=1.37, euclid=1.69
